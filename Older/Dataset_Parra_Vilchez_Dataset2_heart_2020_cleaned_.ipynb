# %% [markdown]
# #Indicadores clave de enfermedades cardíacas"
# >Nombre del Dataset: Dataset2_heart_2020_cleaned.csv
#
# ##INTRODUCCIÓN
# Se realiza una exploración de datos sobre Indicadores clave personales de enfermedades cardíacas, Segun el Centro de control de enfermedades aproximadamente la mitad de todos los estadounidenses (47 %) tienen al menos 1 de 3 factores de riesgo clave de enfermedad cardíaca: presión arterial alta, colesterol alto y tabaquismo.
#
#
# ##PREGUNTAS A RESPONDER:
# *   ¿Comprobar los factores que aumentan las enfermedades del corazon ?
# >Indice de masa corporal
# >Tabaquismo
# >Consumo de alcohol
# >Sexo
# >Rango Etario
# >Raza
# >Diabetes
# >Entre otras

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
import os
drive.mount('/content/gdrive') #montar la carpeta
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# #Carga del dataset en formtato .csv

# %%
# %cd '/content/gdrive/MyDrive/ProyectoDataScience/'
df_heart= pd.read_csv('Dataset2_heart_2020_cleaned.csv',sep=',')
# Out:
# /content/gdrive/.shortcut-targets-by-id/1JBjZRPlZTm-Ax9WZx4quXsWlJqPbkKqm/ProyectoDataScience

# %% [markdown]
# #Entendiendo la data
# ##Mostar el Dataset Preliminar (Sin transformaciones)

# %%
df_heart.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %%
df_heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
# ...

# %%
df_heart.describe(include='all')
# Out:
#        HeartDisease            BMI Smoking AlcoholDrinking  Stroke  \
# count        319795  319795.000000  319795          319795  319795
# unique            2            NaN       2               2       2
# top              No            NaN      No              No      No
# freq         292422            NaN  187887          298018  307726
# mean            NaN      28.325399     NaN             NaN     NaN
# std             NaN       6.356100     NaN             NaN     NaN
# min             NaN      12.020000     NaN             NaN     NaN
# 25%             NaN      24.030000     NaN             NaN     NaN
# 50%             NaN      27.340000     NaN             NaN     NaN
# 75%             NaN      31.420000     NaN             NaN     NaN
# max             NaN      94.850000     NaN             NaN     NaN
#
#         PhysicalHealth   MentalHealth DiffWalking     Sex AgeCategory    Race  \
# count     319795.00000  319795.000000      319795  319795      319795  319795
# ...

# %%
df_heart.shape
# Out:
# (319795, 18)

# %% [markdown]
# Este dataset incluye un total de 319,795 registros de muerte en Chile entre 2016 y 2021.

# %% [markdown]
# #Analisis resumido de las variables (Valores distintos)

# %%
for variable in df_heart.columns:
    print(variable)
    print(df_heart[variable].unique(),"\n")
# Out:
# HeartDisease
# ['No' 'Yes']
#
# BMI
# [16.6  20.34 26.58 ... 62.42 51.46 46.56]
#
# Smoking
# ['Yes' 'No']
#
# AlcoholDrinking
# ['No' 'Yes']
#
# Stroke
# ['No' 'Yes']
#
# PhysicalHealth
# [ 3.  0. 20. 28.  6. 15.  5. 30.  7.  1.  2. 21.  4. 10. 14. 18.  8. 25.
#  16. 29. 27. 17. 24. 12. 23. 26. 22. 19.  9. 13. 11.]
#
# MentalHealth
# [30.  0.  2.  5. 15.  8.  4.  3. 10. 14. 20.  1.  7. 24.  9. 28. 16. 12.
#   6. 25. 17. 18. 21. 29. 22. 13. 23. 27. 26. 11. 19.]
#
# DiffWalking
# ['No' 'Yes']
#
# Sex
# ['Female' 'Male']
#
# AgeCategory
# ['55-59' '80 or older' '65-69' '75-79' '40-44' '70-74' '60-64' '50-54'
#  '45-49' '18-24' '35-39' '30-34' '25-29']
#
# Race
# ['White' 'Black' 'Asian' 'American Indian/Alaskan Native' 'Other'
#  'Hispanic']
#
# Diabetic
# ['Yes' 'No' 'No, borderline diabetes' 'Yes (during pregnancy)']
#
# PhysicalActivity
# ['Yes' 'No']
#
# GenHealth
# ['Very good' 'Fair' 'Good' 'Poor' 'Excellent']
#
# SleepTime
# ...

# %% [markdown]
# ##Distribución de las variables en el dataset

# %%
for col in df_heart:
    print('* * * * * * * * * *',col,'* * * * * * * * * *')
    print(df_heart[col].value_counts(ascending=True))
    print(df_heart[col].value_counts(normalize=True))
    print('******************************************')
# Out:
# * * * * * * * * * * HeartDisease * * * * * * * * * *
# Yes     27373
# No     292422
# Name: HeartDisease, dtype: int64
# No     0.914405
# Yes    0.085595
# Name: HeartDisease, dtype: float64
# ******************************************
# * * * * * * * * * * BMI * * * * * * * * * *
# 46.56       1
# 45.71       1
# 29.67       1
# 57.41       1
# 44.31       1
#          ...
# 27.12    2525
# 24.41    2696
# 27.44    2723
# 27.46    2767
# 26.63    3762
# Name: BMI, Length: 3604, dtype: int64
# 26.63    0.011764
# 27.46    0.008652
# 27.44    0.008515
# 24.41    0.008430
# 27.12    0.007896
#            ...
# 59.85    0.000003
# 50.59    0.000003
# 92.53    0.000003
# 62.95    0.000003
# 46.56    0.000003
# Name: BMI, Length: 3604, dtype: float64
# ******************************************
# * * * * * * * * * * Smoking * * * * * * * * * *
# Yes    131908
# No     187887
# Name: Smoking, dtype: int64
# No     0.587523
# Yes    0.412477
# Name: Smoking, dtype: float64
# ...

# %% [markdown]
# ##Contar valores NA por columna

# %%
df_heart.shape
# Out:
# (319795, 18)

# %%
print(df_heart.isna().sum())
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %% [markdown]
# ##Eliminar columnas vacias

# %%
df_heart = df_heart.drop(columns=[])  # No se eliminan columnas vacias, ya el dataset venia depurado desde la fuente.
df_heart.shape
# Out:
# (319795, 18)

# %%
df_heart.corr()
# Out:
#                      BMI  PhysicalHealth  MentalHealth  SleepTime
# BMI             1.000000        0.109788      0.064131  -0.051822
# PhysicalHealth  0.109788        1.000000      0.287987  -0.061387
# MentalHealth    0.064131        0.287987      1.000000  -0.119717
# SleepTime      -0.051822       -0.061387     -0.119717   1.000000

# %% [markdown]
# # Notas
# El dataset contiene 18 variables (9 booleans, 5 strings y 4 decimals).
