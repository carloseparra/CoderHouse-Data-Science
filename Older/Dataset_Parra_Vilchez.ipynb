# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
import os
drive.mount('/content/gdrive') #montar la carpeta
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# #Cargar Archivos .xlsx del Dataset

# %%
# %cd '/content/gdrive/MyDrive/ProyectoDataScience/Dataset'
df_Dataset1 = pd.DataFrame(data=pd.read_excel('Articulos.xlsx'))
df_Lista_Final = pd.DataFrame(data=pd.read_excel('Lista-Final.xlsx'))
df_Lista_Mayorista = pd.DataFrame(data=pd.read_excel('Lista-Mayorista.xlsx'))
df_Ventas = pd.DataFrame(data=pd.read_excel('Ventas.xlsx'))
df_Ventas_2018 = pd.DataFrame(data=pd.read_excel('Ventas-2018.xlsx'))
df_Ventas_2019 = pd.DataFrame(data=pd.read_excel('Ventas-2019.xlsx'))
df_Ventas_2020 = pd.DataFrame(data=pd.read_excel('Ventas-2020.xlsx'))
# Out:
# /content/gdrive/.shortcut-targets-by-id/1JBjZRPlZTm-Ax9WZx4quXsWlJqPbkKqm/ProyectoDataScience/Dataset

# %% [markdown]
# #Listado de Articulos var: df_Articulos

# %%
df_Articulos
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-d1fb093d1f40> in <module>
# ----> 1 df_Articulos
#
# NameError: name 'df_Articulos' is not defined

# %%
df_Articulos.info()

# %% [markdown]
# #Listas de precios

# %% [markdown]
# ##Mostrar lista de precio final Var: df_Lista_Final

# %%
df_Lista_Final

# %%
df_Lista_Final.info()

# %% [markdown]
# ##Mostrar lista de precio mayorista Var: df_Lista_Mayorista

# %%
df_Lista_Mayorista

# %%
df_Lista_Mayorista.info()

# %% [markdown]
# #Listados de Venta

# %% [markdown]
# ##Datasets Ventas - Var: df_Ventas

# %%
df_Ventas

# %%
df_Ventas.info()

# %% [markdown]
# ##Dataset Ventas 2018 - Var: df_Ventas_2018

# %%
df_Ventas_2018

# %%
df_Ventas_2018.info()

# %% [markdown]
# ##Dataset Ventas 2019 - Var: df_Ventas_2019

# %%
df_Ventas_2019

# %%
df_Ventas_2019.info()

# %% [markdown]
# ##Dataset Ventas 2020 - Var: df_Ventas_2020

# %%
df_Ventas_2020

# %%
df_Ventas_2020.info()

# %%
df_ventas_total =pd.concat([df_Ventas_2018, df_Ventas_2019, df_Ventas_2020])
df_ventas_total

# %%
df_ventas_total.info()

# %%
df_ventas_total['Precio Unitario'].describe()

# %% [markdown]
# #Variables potencialmente interesantes
# >Analisis
# >>Productos mas vendidos
# Mejores vendedores
# Mejores meses del año
# Top Ventas
# Mejores clientes
#
# >Predicción
# >>Comportamiento futuro de la venta
# Inferir que productos son susceptibles a descuentos por temporadas
